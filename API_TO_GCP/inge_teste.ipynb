# %%
import requests
import pandas as pd 

ibge = 'https://servicodados.ibge.gov.br/api/v1/localidades/municipios?view=nivelado'

residuos = 'https://dadosabertos.ibama.gov.br/dados/RAPP/residuoSolidosTransportador/relatorio.xml'

# %%
pd.to_parquet.help
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.to_parquet.help
#
# AttributeError: module 'pandas' has no attribute 'to_parquet'

# %%
dados_ibge = requests.get(ibge)
dados_residuos = requests.get(residuos)
ibge_json = dados_ibge.json()
#residuos_json = dados_residuos.json()

# %%
#df = pd.json_normalize(ibge_json, sep = '_')
df = pd.json_normalize(dados_residuos, sep = '_')

#df_ibge = pd.DataFrame(df)
df_residuos = pd.DataFrame(df)
display(df_residuos.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ibge_columns = ["id_municipio", "nome_municipio","id_microrregiao","nome_microrregiao", "id_mesorregiao", "nome_mesorregiao", "id_regiao_imediata", "nome_regiao_imediata", "id_regiao_intermediaria", "nome_regiao_intermediaria", "id_uf","sigla_uf", "nome_uf", "id_regiao", "sigla_regiao", "nome_regiao"]
df_ibge.columns = ibge_columns

display(df_ibge)
#print(df_ibge.head())
# Out:
#       id_municipio         nome_municipio  id_microrregiao  \
# 0          1100015  Alta Floresta D'Oeste          11006.0
# 1          1100023              Ariquemes          11003.0
# 2          1100031                 Cabixi          11008.0
# 3          1100049                 Cacoal          11006.0
# 4          1100056             Cerejeiras          11008.0
# ...            ...                    ...              ...
# 5566       5222005             Vianópolis          52016.0
# 5567       5222054         Vicentinópolis          52015.0
# 5568       5222203               Vila Boa          52012.0
# 5569       5222302          Vila Propício          52012.0
# 5570       5300108               Brasília          53001.0
#
#         nome_microrregiao  id_mesorregiao   nome_mesorregiao  \
# 0                  Cacoal          1102.0  Leste Rondoniense
# 1               Ariquemes          1102.0  Leste Rondoniense
# 2       Colorado do Oeste          1102.0  Leste Rondoniense
# 3                  Cacoal          1102.0  Leste Rondoniense
# 4       Colorado do Oeste          1102.0  Leste Rondoniense
# ...                   ...             ...                ...
# 5566         Pires do Rio          5205.0         Sul Goiano
# 5567           Meia Ponte          5205.0         Sul Goiano
# 5568  Entorno de Brasília          5204.0       Leste Goiano
# 5569  Entorno de Brasília          5204.0       Leste Goiano
# 5570             Brasília          5301.0   Distrito Federal
#
#       id_regiao_imediata        nome_regiao_imediata  id_regiao_intermediaria  \
# 0                 110005                      Cacoal                     1102
# 1                 110002                   Ariquemes                     1101
# 2                 110006                     Vilhena                     1102
# 3                 110005                      Cacoal                     1102
# 4                 110006                     Vilhena                     1102
# ...                  ...                         ...                      ...
# 5566              520002                    Anápolis                     5201
# 5567              520009                 Piracanjuba                     5202
# 5568              520022             Flores de Goiás                     5206
# 5569              520018  Ceres - Rialma - Goianésia                     5205
# 5570              530001            Distrito Federal                     5301
#
#              nome_regiao_intermediaria  id_uf sigla_uf           nome_uf  \
# 0                            Ji-Paraná     11       RO          Rondônia
# 1                          Porto Velho     11       RO          Rondônia
# 2                            Ji-Paraná     11       RO          Rondônia
# 3                            Ji-Paraná     11       RO          Rondônia
# 4                            Ji-Paraná     11       RO          Rondônia
# ...                                ...    ...      ...               ...
# 5566                           Goiânia     52       GO             Goiás
# 5567                         Itumbiara     52       GO             Goiás
# 5568  Luziânia - Águas Lindas de Goiás     52       GO             Goiás
# 5569                Porangatu - Uruaçu     52       GO             Goiás
# 5570                  Distrito Federal     53       DF  Distrito Federal
#
#       id_regiao sigla_regiao   nome_regiao
# 0             1            N         Norte
# 1             1            N         Norte
# 2             1            N         Norte
# 3             1            N         Norte
# 4             1            N         Norte
# ...         ...          ...           ...
# 5566          5           CO  Centro-Oeste
# 5567          5           CO  Centro-Oeste
# 5568          5           CO  Centro-Oeste
# 5569          5           CO  Centro-Oeste
# 5570          5           CO  Centro-Oeste
#
# [5571 rows x 16 columns]

# %%
df.to_parquet.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.to_parquet.help
#
# NameError: name 'df' is not defined
